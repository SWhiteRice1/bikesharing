# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
df=pd.read_csv('../bikesharing/201908-citibike-tripdata 2.csv')
df.sample(10)
# Out:
#          tripduration                 starttime                  stoptime  \
# 1432651           501  2019-08-19 18:17:36.4960  2019-08-19 18:25:57.6660
# 1611603           200  2019-08-22 05:58:45.2820  2019-08-22 06:02:05.7890
# 1203426           365  2019-08-16 14:51:26.2920  2019-08-16 14:57:31.3980
# 1496567          1660  2019-08-20 16:10:40.2420  2019-08-20 16:38:20.9940
# 203119           1635  2019-08-03 13:40:16.5850  2019-08-03 14:07:32.5090
# 1859483          1293  2019-08-25 15:34:47.5220  2019-08-25 15:56:21.2410
# 2026522           736  2019-08-27 17:41:34.6910  2019-08-27 17:53:51.5340
# 2192724           995  2019-08-29 20:00:04.5160  2019-08-29 20:16:40.2180
# 1558304           662  2019-08-21 10:11:16.6780  2019-08-21 10:22:18.8230
# 1328974          1084  2019-08-18 08:36:57.5380  2019-08-18 08:55:01.9170
#
#          start station id              start station name  \
# 1432651             445.0              E 10 St & Avenue A
# ...

# %%
# 2. Check the datatypes of your columns. 
df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
new_tripduration = df.tripduration
# print(new_tripduration)

new_tripduration_datetime = pd.to_datetime(new_tripduration, unit='s')
print(new_tripduration_datetime)

# Add a new column for the converted trip duration
df['new_tripduration'] = new_tripduration_datetime

# Convert the numeric gender values to string values 
# df['gender'].replace([0,1,2],['Unknown','Male','Female'],inplace=True)
# df.head()
# Out:
# 0         1970-01-01 00:06:33
# 1         1970-01-01 00:10:27
# 2         1970-01-01 00:18:52
# 3         1970-01-01 00:29:40
# 4         1970-01-01 00:25:17
#                   ...
# 2344219   1970-01-01 00:03:36
# 2344220   1970-01-01 00:01:57
# 2344221   1970-01-01 00:26:54
# 2344222   1970-01-01 00:21:41
# 2344223   1970-01-01 00:06:59
# Name: tripduration, Length: 2344224, dtype: datetime64[ns]

# %%
# 4. Check the datatypes of your columns. 
df.dtypes
# Out:
# tripduration                        int64
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# new_tripduration           datetime64[ns]
# dtype: object

# %%
# 5. Export the Dataframe as a new CSV file without the index.
df.to_csv("../bikesharing_challenge.csv",index=False)

# %%
df.head(10)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1           627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2          1132  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3          1780  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4          1517  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
# 5           632  2019-08-01 00:00:11.8060  2019-08-01 00:10:43.9590
# 6           117  2019-08-01 00:00:18.2010  2019-08-01 00:02:15.8600
# 7           378  2019-08-01 00:00:22.0840  2019-08-01 00:06:40.9350
# 8          1102  2019-08-01 00:00:22.0870  2019-08-01 00:18:44.3890
# 9          1733  2019-08-01 00:00:22.5580  2019-08-01 00:29:15.9080
#
#    start station id              start station name  start station latitude  \
# 0             531.0          Forsyth St & Broome St               40.718939
# ...
